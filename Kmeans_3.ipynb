# %% [markdown]
# <a href="https://colab.research.google.com/github/Monic123-cloud/Fundamentos/blob/main/Kmeans_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def plot_data(X):
     plt.plot(X[:, 0], X[:, 1], 'k.', markersize=2)

def plot_centroids(centroids, weights=None, circle_color='w', cross_color='k'):
    if weights is not None:
         centroids = centroids[weights > weights.max() / 10]
    plt.scatter(centroids[:, 0], centroids[:, 1],
                 marker='o', s=30, linewidths=8,
                 color=circle_color, zorder=10, alpha=0.9)
    plt.scatter(centroids[:, 0], centroids[:, 1],
                 marker='x', s=50, linewidths=50,
                 color=cross_color, zorder=11, alpha=1)

def plot_decision_boundaries(clusterer, X, resolution=1000, show_centroids=True,
                             show_xlabels=True, show_ylabels=True):
    mins = X.min(axis=0) - 0.1
    maxs = X.max(axis=0) + 0.1
    xx, yy = np.meshgrid(np.linspace(mins[0], maxs[0], resolution),
                         np.linspace(mins[1], maxs[1], resolution))
    Z = clusterer.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)

    plt.contourf(Z, extent=(mins[0], maxs[0], mins[1], maxs[1]),
                cmap="Pastel2")
    plt.contour(Z, extent=(mins[0], maxs[0], mins[1], maxs[1]),
                 linewidths=1, colors='k')
    plot_data(X)
    if show_centroids:
         plot_centroids(clusterer.cluster_centers_)

    if show_xlabels:
        plt.xlabel("$x_1$", fontsize=14)
    else:
         plt.tick_params(labelbottom=False)
    if show_ylabels:
         plt.ylabel("$x_2$", fontsize=14, rotation=0)
    else:
         plt.tick_params(labelleft=False)

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
def plot_data(X):
     plt.plot(X[:, 0], X[:, 1], 'k.', markersize=2)

def plot_centroids(centroids, weights=None, circle_color='w', cross_color='k'):
    if weights is not None:
         centroids = centroids[weights > weights.max() / 10]
    plt.scatter(centroids[:, 0], centroids[:, 1],
                 marker='o', s=30, linewidths=8,
                 color=circle_color, zorder=10, alpha=0.9)
    plt.scatter(centroids[:, 0], centroids[:, 1],
                 marker='x', s=50, linewidths=50,
                 color=cross_color, zorder=11, alpha=1)

def plot_decision_boundaries(clusterer, X, resolution=1000, show_centroids=True,
                             show_xlabels=True, show_ylabels=True):
    mins = X.min(axis=0) - 0.1
    maxs = X.max(axis=0) + 0.1
    xx, yy = np.meshgrid(np.linspace(mins[0], maxs[0], resolution),
                         np.linspace(mins[1], maxs[1], resolution))
    Z = clusterer.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)

    plt.contourf(Z, extent=(mins[0], maxs[0], mins[1], maxs[1]),
                cmap="Pastel2")
    plt.contour(Z, extent=(mins[0], maxs[0], mins[1], maxs[1]),
                 linewidths=1, colors='k')
    plot_data(X)
    if show_centroids:
         plot_centroids(clusterer.cluster_centers_)

    if show_xlabels:
        plt.xlabel("$x_1$", fontsize=14)
    else:
         plt.tick_params(labelbottom=False)
    if show_ylabels:
         plt.ylabel("$x_2$", fontsize=14, rotation=0)
    else:
         plt.tick_params(labelleft=False)

# %% [markdown]
# # Task
# Analiza el dataset Iris aplicando el algoritmo K-Means a la longitud y anchura del pétalo. Realiza el agrupamiento con 2, 3 y 4 clústeres. Para cada caso, visualiza los resultados, muestra la posición de los centroides, identifica a qué clúster asigna el algoritmo el punto (2.5, 1) y calcula la distancia de dicho punto a cada centroide.

# %% [markdown]
# ## Cargar y preparar los datos
#
# ### Subtask:
# Cargar el dataset Iris y seleccionar únicamente las columnas correspondientes a la longitud y anchura del pétalo.

# %% [markdown]
# **Reasoning**:
# The subtask requires loading the Iris dataset and selecting specific columns. This can be done by importing `load_iris` from `sklearn.datasets`, loading the dataset, and then extracting and selecting the relevant columns.

# %%
from sklearn.datasets import load_iris

# Load the Iris dataset
iris = load_iris()

# Extract data (features) and target
X_full = iris.data
y = iris.target

# Select the third and fourth columns (petal length and petal width)
X = X_full[:, [2, 3]]

# %% [markdown]
# ## Aplicar k-means con 2 clústeres
#
# ### Subtask:
# Entrenar el modelo K-Means con `n_clusters=2`.

# %% [markdown]
# **Reasoning**:
# Import KMeans, instantiate the model with n_clusters=2 and random_state=42, and fit the model to the data.

# %%
from sklearn.cluster import KMeans

kmeans_2 = KMeans(n_clusters=2, random_state=42, n_init=10)
kmeans_2.fit(X)
# Out:
# KMeans(n_clusters=2, n_init=10, random_state=42)

# %% [markdown]
# ## Visualizar resultados (2 clústeres)
#
# ### Subtask:
# Graficar los datos y los centroides obtenidos con 2 clústeres utilizando las funciones `plot_data` y `plot_centroids`.

# %% [markdown]
# **Reasoning**:
# Create a figure and axes, then call the plot_decision_boundaries function to visualize the clustering results with 2 clusters and add a title to the plot.

# %%
plt.figure(figsize=(8, 6))
plot_decision_boundaries(kmeans_2, X)
plt.title("K-Means Clustering with 2 Clusters")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3138085652.py in <cell line: 0>()
# ----> 1 plt.figure(figsize=(8, 6))
#       2 plot_decision_boundaries(kmeans_2, X)
#       3 plt.title("K-Means Clustering with 2 Clusters")
#       4 plt.show()
#
# NameError: name 'plt' is not defined

# %% [markdown]
# **Reasoning**:
# The previous command failed because `plt` was not defined. Although `matplotlib.pyplot` was imported in a previous cell, it was not imported in the current session or the relevant cells were not executed in the expected order. I will regenerate the code block including the necessary import to fix this issue.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
plot_decision_boundaries(kmeans_2, X)
plt.title("K-Means Clustering with 2 Clusters")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2176852458.py in <cell line: 0>()
#       2
#       3 plt.figure(figsize=(8, 6))
# ----> 4 plot_decision_boundaries(kmeans_2, X)
#       5 plt.title("K-Means Clustering with 2 Clusters")
#       6 plt.show()
#
# NameError: name 'plot_decision_boundaries' is not defined

# %% [markdown]
# **Reasoning**:
# The previous command failed because `plot_decision_boundaries` was not defined. This is because the cells defining the plotting functions were not executed or were executed in a session that is no longer active. I will include the function definitions in the current code block to ensure they are available when called.

# %%
def plot_data(X):
     plt.plot(X[:, 0], X[:, 1], 'k.', markersize=2)

def plot_centroids(centroids, weights=None, circle_color='w', cross_color='k'):
    if weights is not None:
         centroids = centroids[weights > weights.max() / 10]
    plt.scatter(centroids[:, 0], centroids[:, 1],
                 marker='o', s=30, linewidths=8,
                 color=circle_color, zorder=10, alpha=0.9)
    plt.scatter(centroids[:, 0], centroids[:, 1],
                 marker='x', s=50, linewidths=50,
                 color=cross_color, zorder=11, alpha=1)

def plot_decision_boundaries(clusterer, X, resolution=1000, show_centroids=True,
                             show_xlabels=True, show_ylabels=True):
    mins = X.min(axis=0) - 0.1
    maxs = X.max(axis=0) + 0.1
    xx, yy = np.meshgrid(np.linspace(mins[0], maxs[0], resolution),
                         np.linspace(mins[1], maxs[1], resolution))
    Z = clusterer.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)

    plt.contourf(Z, extent=(mins[0], maxs[0], mins[1], maxs[1]),
                cmap="Pastel2")
    plt.contour(Z, extent=(mins[0], maxs[0], mins[1], maxs[1]),
                 linewidths=1, colors='k')
    plot_data(X)
    if show_centroids:
         plot_centroids(clusterer.cluster_centers_)

    if show_xlabels:
        plt.xlabel("$x_1$", fontsize=14)
    else:
         plt.tick_params(labelbottom=False)
    if show_ylabels:
         plt.ylabel("$x_2$", fontsize=14, rotation=0)
    else:
         plt.tick_params(labelleft=False)

plt.figure(figsize=(8, 6))
plot_decision_boundaries(kmeans_2, X)
plt.title("K-Means Clustering with 2 Clusters")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4047586599.py in <cell line: 0>()
#      39
#      40 plt.figure(figsize=(8, 6))
# ---> 41 plot_decision_boundaries(kmeans_2, X)
#      42 plt.title("K-Means Clustering with 2 Clusters")
#      43 plt.show()
#
# /tmp/ipython-input-4047586599.py in plot_decision_boundaries(clusterer, X, resolution, show_centroids, show_xlabels, show_ylabels)
#      16     mins = X.min(axis=0) - 0.1
#      17     maxs = X.max(axis=0) + 0.1
# ---> 18     xx, yy = np.meshgrid(np.linspace(mins[0], maxs[0], resolution),
#      19                          np.linspace(mins[1], maxs[1], resolution))
#      20     Z = clusterer.predict(np.c_[xx.ravel(), yy.ravel()])
#
# NameError: name 'np' is not defined

# %% [markdown]
# **Reasoning**:
# The previous command failed because `np` was not defined. This is because the cell importing `numpy` was not executed or the session is no longer active. I will include the import of `numpy` along with the function definitions and the plotting code to ensure all necessary components are available.

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_data(X):
     plt.plot(X[:, 0], X[:, 1], 'k.', markersize=2)

def plot_centroids(centroids, weights=None, circle_color='w', cross_color='k'):
    if weights is not None:
         centroids = centroids[weights > weights.max() / 10]
    plt.scatter(centroids[:, 0], centroids[:, 1],
                 marker='o', s=30, linewidths=8,
                 color=circle_color, zorder=10, alpha=0.9)
    plt.scatter(centroids[:, 0], centroids[:, 1],
                 marker='x', s=50, linewidths=50,
                 color=cross_color, zorder=11, alpha=1)

def plot_decision_boundaries(clusterer, X, resolution=1000, show_centroids=True,
                             show_xlabels=True, show_ylabels=True):
    mins = X.min(axis=0) - 0.1
    maxs = X.max(axis=0) + 0.1
    xx, yy = np.meshgrid(np.linspace(mins[0], maxs[0], resolution),
                         np.linspace(mins[1], maxs[1], resolution))
    Z = clusterer.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)

    plt.contourf(Z, extent=(mins[0], maxs[0], mins[1], maxs[1]),
                cmap="Pastel2")
    plt.contour(Z, extent=(mins[0], maxs[0], mins[1], maxs[1]),
                 linewidths=1, colors='k')
    plot_data(X)
    if show_centroids:
         plot_centroids(clusterer.cluster_centers_)

    if show_xlabels:
        plt.xlabel("$x_1$", fontsize=14)
    else:
         plt.tick_params(labelbottom=False)
    if show_ylabels:
         plt.ylabel("$x_2$", fontsize=14, rotation=0)
    else:
         plt.tick_params(labelleft=False)

plt.figure(figsize=(8, 6))
plot_decision_boundaries(kmeans_2, X)
plt.title("K-Means Clustering with 2 Clusters")
plt.show()

# %% [markdown]
# ## Analizar punto (2.5, 1) (2 clústeres)
#
# ### Subtask:
# Predecir a qué clúster pertenece el punto (2.5, 1) y calcular su distancia a cada uno de los 2 centroides.

# %% [markdown]
# **Reasoning**:
# Define the point, predict its cluster, get the centroids, and calculate the distances using NumPy and scikit-learn.

# %%
point = np.array([[2.5, 1]])
predicted_cluster = kmeans_2.predict(point)
centroids = kmeans_2.cluster_centers_
distances = np.linalg.norm(centroids - point, axis=1)

print(f"The point {point[0]} belongs to cluster: {predicted_cluster[0]}")
print(f"Distance to cluster 0 centroid: {distances[0]:.4f}")
print(f"Distance to cluster 1 centroid: {distances[1]:.4f}")
# Out:
# The point [2.5 1. ] belongs to cluster: 1
# Distance to cluster 0 centroid: 2.5193
# Distance to cluster 1 centroid: 1.2487

# %% [markdown]
# ## Aplicar k-means con 3 clústeres
#
# ### Subtask:
# Entrenar el modelo K-Means con `n_clusters=3`.

# %% [markdown]
# **Reasoning**:
# The task requires training a KMeans model with 3 clusters. This involves importing the KMeans class, instantiating it with the specified parameters, and fitting it to the data.

# %%
kmeans_3 = KMeans(n_clusters=3, random_state=42, n_init=10)
kmeans_3.fit(X)
# Out:
# KMeans(n_clusters=3, n_init=10, random_state=42)

# %% [markdown]
# ## Visualizar resultados (3 clústeres)
#
# ### Subtask:
# Graficar los datos y los centroides obtenidos con 3 clústeres utilizando las funciones `plot_data` and `plot_centroids`.

# %% [markdown]
# **Reasoning**:
# Create a new figure, plot the decision boundaries and centroids for the 3-cluster K-Means model, add a title, and display the plot.

# %%
plt.figure(figsize=(8, 6))
plot_decision_boundaries(kmeans_3, X)
plt.title("K-Means Clustering with 3 Clusters")
plt.show()

# %% [markdown]
# ## Analizar punto (2.5, 1) (3 clústeres)
#
# ### Subtask:
# Predecir a qué clúster pertenece el punto (2.5, 1) y calcular su distancia a cada uno de los 3 centroides.

# %% [markdown]
# **Reasoning**:
# Define the point, predict its cluster, get the centroids, calculate distances, and print the results.

# %%
point = np.array([[2.5, 1]])
predicted_cluster = kmeans_3.predict(point)
centroids = kmeans_3.cluster_centers_
distances = np.linalg.norm(centroids - point, axis=1)

print(f"The point {point[0]} belongs to cluster: {predicted_cluster[0]}")
for i, dist in enumerate(distances):
    print(f"Distance to cluster {i} centroid: {dist:.4f}")
# Out:
# The point [2.5 1. ] belongs to cluster: 1
# Distance to cluster 0 centroid: 3.2651
# Distance to cluster 1 centroid: 1.2829
# Distance to cluster 2 centroid: 1.8020

# %% [markdown]
# ## Aplicar k-means con 4 clústeres
#
# ### Subtask:
# Entrenar el modelo K-Means con `n_clusters=4`.

# %% [markdown]
# **Reasoning**:
# Import the KMeans class and instantiate and fit the KMeans model with 4 clusters to the data.

# %%
from sklearn.cluster import KMeans

kmeans_4 = KMeans(n_clusters=4, random_state=42, n_init=10)
kmeans_4.fit(X)
# Out:
# KMeans(n_clusters=4, n_init=10, random_state=42)

# %% [markdown]
# ## Visualizar resultados (4 clústeres)
#
# ### Subtask:
# Graficar los datos y los centroides obtenidos con 4 clústeres utilizando las funciones `plot_data` and `plot_centroids`.

# %% [markdown]
# **Reasoning**:
# Create a figure, plot the decision boundaries with 4 clusters, add a title, and display the plot.

# %%
plt.figure(figsize=(8, 6))
plot_decision_boundaries(kmeans_4, X)
plt.title("K-Means Clustering with 4 Clusters")
plt.show()

# %% [markdown]
# ## Analizar punto (2.5, 1) (4 clústeres)
#
# ### Subtask:
# Predecir a qué clúster pertenece el punto (2.5, 1) y calcular su distancia a cada uno de los 4 centroides.

# %% [markdown]
# **Reasoning**:
# Predict the cluster for the point (2.5, 1) using the 4-cluster KMeans model and calculate the distance from this point to each of the 4 centroids.

# %%
point = np.array([[2.5, 1]])
predicted_cluster = kmeans_4.predict(point)
centroids = kmeans_4.cluster_centers_
distances = np.linalg.norm(centroids - point, axis=1)

print(f"The point {point[0]} belongs to cluster: {predicted_cluster[0]}")
for i, dist in enumerate(distances):
    print(f"Distance to cluster {i} centroid: {dist:.4f}")
# Out:
# The point [2.5 1. ] belongs to cluster: 1
# Distance to cluster 0 centroid: 3.4848
# Distance to cluster 1 centroid: 1.2829
# Distance to cluster 2 centroid: 1.4170
# Distance to cluster 3 centroid: 2.3492
